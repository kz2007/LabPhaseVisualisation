# %%
import matplotlib.pyplot as plt

count_classes = pd.value_counts(data['Class'], sort = True)

count_classes.plot(kind = 'bar', rot=0)

plt.title("Transaction Class Distribution")

plt.xticks(range(2), ["Normal Transaction", "Fraud Case"])

plt.xlabel("Class")

plt.ylabel("Frequency")

plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\Khaled\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')
bins = 50
ax1.hist(fraud_dataset.Amount, bins = bins)
ax1.set_title('Fraud')
ax2.hist(normal_dataset.Amount, bins = bins)
ax2.set_title('Normal')
plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show()
